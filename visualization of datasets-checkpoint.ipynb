# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns
# Out:
# C:\Users\M VASIL ANSARI\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#importing training_dataset
training_dataset=pd.read_csv("train.csv",dtype='object')

# %%
#training_dataset
training_dataset
# Out:
#             id blood_group  Gender Age Driving_License Region_Code  \
# 0       223723           O  Female  23               1        18.0
# 1       102674         AB-    Male  44               1        23.0
# 2        15567         AB+    Male  23               1        41.0
# 3       222937           O    Male  78               1        15.0
# 4        32565          B+  Female  25               1        44.0
# ...        ...         ...     ...  ..             ...         ...
# 266771  349992           O    Male  24               1        28.0
# 266772  260914         AB+    Male  41               1        14.0
# 266773  214966         AB+    Male  44               1         3.0
# 266774  200722          B+    Male  38               1        30.0
# 266775  438772           O    Male  48               1        41.0
#
#        Previously_Insured Vehicle_Age Vehicle_Damage Annual_Premium  \
# 0                       1    < 1 Year             No        29223.0
# 1                       0    1-2 Year            Yes        28501.0
# 2                       0    < 1 Year            Yes        32590.0
# 3                       1    1-2 Year             No         2630.0
# 4                       1    < 1 Year             No        31821.0
# ...                   ...         ...            ...            ...
# 266771                  1    < 1 Year             No        49840.0
# 266772                  0    1-2 Year            Yes        31399.0
# 266773                  0    1-2 Year            Yes        21292.0
# 266774                  1    1-2 Year            Yes        29448.0
# 266775                  0    1-2 Year            Yes        39092.0
#
#        Policy_Sales_Channel Vintage mother_age father_age accepted
# 0                     152.0      89         70         65        0
# 1                      26.0     111         61         66        1
# 2                     152.0      71         67         78        0
# 3                      14.0     245         74         63        0
# 4                     152.0      59         73         62        0
# ...                     ...     ...        ...        ...      ...
# 266771                152.0      39         72         74        0
# 266772                 26.0      25         63         75        0
# 266773                 26.0      36         73         70        0
# 266774                 26.0     117         62         76        0
# 266775                 26.0     114         68         78        0
#
# [266776 rows x 15 columns]

# %%
#number of missing values in each column
training_dataset.isna().sum()
# Out:
# id                      0
# blood_group             0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# mother_age              0
# father_age              0
# accepted                0
# dtype: int64

# %%
#size of training_dataset(number of samples,number of features)
training_dataset.shape
# Out:
# (266776, 13)

# %%
#dropping values in training_dataset
training_dataset.drop(['id','blood_group'],axis=1,inplace=True)

# %%
training_dataset
# Out:
#         Gender Age Driving_License Region_Code Previously_Insured Vehicle_Age  \
# 0       Female  23               1        18.0                  1    < 1 Year
# 1         Male  44               1        23.0                  0    1-2 Year
# 2         Male  23               1        41.0                  0    < 1 Year
# 3         Male  78               1        15.0                  1    1-2 Year
# 4       Female  25               1        44.0                  1    < 1 Year
# ...        ...  ..             ...         ...                ...         ...
# 266771    Male  24               1        28.0                  1    < 1 Year
# 266772    Male  41               1        14.0                  0    1-2 Year
# 266773    Male  44               1         3.0                  0    1-2 Year
# 266774    Male  38               1        30.0                  1    1-2 Year
# 266775    Male  48               1        41.0                  0    1-2 Year
#
#        Vehicle_Damage Annual_Premium Policy_Sales_Channel Vintage mother_age  \
# 0                  No        29223.0                152.0      89         70
# 1                 Yes        28501.0                 26.0     111         61
# 2                 Yes        32590.0                152.0      71         67
# 3                  No         2630.0                 14.0     245         74
# 4                  No        31821.0                152.0      59         73
# ...               ...            ...                  ...     ...        ...
# 266771             No        49840.0                152.0      39         72
# 266772            Yes        31399.0                 26.0      25         63
# 266773            Yes        21292.0                 26.0      36         73
# 266774            Yes        29448.0                 26.0     117         62
# 266775            Yes        39092.0                 26.0     114         68
#
#        father_age accepted
# 0              65        0
# 1              66        1
# 2              78        0
# 3              63        0
# 4              62        0
# ...           ...      ...
# 266771         74        0
# 266772         75        0
# 266773         70        0
# 266774         76        0
# 266775         78        0
#
# [266776 rows x 13 columns]

# %%
#columns in training_dataset
training_dataset.columns
# Out:
# Index(['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured',
#        'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'mother_age', 'father_age',
#        'accepted'],
#       dtype='object')

# %%
#description of training_dataset
training_dataset.describe()
# Out:
#         Gender     Age Driving_License Region_Code Previously_Insured  \
# count   266776  266776          266776      266776             266776
# unique       2      66               2          53                  2
# top       Male      24               1        28.0                  0
# freq    144510   18182          266218       74601             144770
#
#        Vehicle_Age Vehicle_Damage Annual_Premium Policy_Sales_Channel Vintage  \
# count       266776         266776         266776               266776  266776
# unique           3              2          44880                  152     290
# top       1-2 Year            Yes         2630.0                152.0     256
# freq        140489         134910          45387                94116    1009
#
#        mother_age father_age accepted
# count      266776     266776   266776
# unique         20         20        2
# top            79         78        0
# freq        13525      13561   234079

# %%
#plotting graph for categorical features
def plot_graph(dataset,feature_name,llist):
    freq=[]
    for i in llist:
        count=0
        for j in range(dataset.shape[0]):
            a=dataset[feature_name][int(j)]
            #print(a)
            if a==i:
                count+=1
        freq.append(count)
    print(llist)
    print(freq)
    plt.bar(llist,freq)
    plt.show()
    return sum(freq)

# %%
#plotting graph for categorical values
a=plot_graph(training_dataset,'Gender',['Male','Female'])
b=plot_graph(training_dataset,'Driving_License',['0','1'])   #must be removed see plot-2
c=plot_graph(training_dataset, 'Previously_Insured',['0','1'])
d=plot_graph(training_dataset, 'Vehicle_Damage',['Yes','No'])
e=plot_graph(training_dataset, 'accepted',['0','1'])
# Out:
# ['Male', 'Female']
# [144510, 122266]
# ['0', '1']
# [558, 266218]
# ['0', '1']
# [144770, 122006]
# ['Yes', 'No']
# [134910, 131866]
# ['0', '1']
# [234079, 32697]

# %%
f=plot_graph(training_dataset,'Vehicle_Age',['< 1 Year', '1-2 Year', '> 2 Years'])
# Out:
# ['< 1 Year', '1-2 Year', '> 2 Years']
# [115089, 140489, 11198]

# %%
print(a,b,c,d,e,f)
# Out:
# 266776 266776 266776 266776 266776 266776

# %%
def unique_values(dataset,feature_name):
    l=list()
    for i in range(dataset.shape[0]):
        if dataset[feature_name][i] not in l:
            l.append(dataset[feature_name][i])
    return l

# %%
vehicle_age_unique_values=unique_values(training_dataset,'Vehicle_Age');

# %%
vehicle_age_unique_values
# Out:
# ['< 1 Year', '1-2 Year', '> 2 Years']

# %%
#importing features and labels from training_dataset

X=training_dataset.iloc[:,[0,1,3,4,5,6,7,8,9,10,11]]
Y=training_dataset.iloc[:,12]

# %%
X
# Out:
#         Gender Age Region_Code Previously_Insured Vehicle_Age Vehicle_Damage  \
# 0       Female  23        18.0                  1    < 1 Year             No
# 1         Male  44        23.0                  0    1-2 Year            Yes
# 2         Male  23        41.0                  0    < 1 Year            Yes
# 3         Male  78        15.0                  1    1-2 Year             No
# 4       Female  25        44.0                  1    < 1 Year             No
# ...        ...  ..         ...                ...         ...            ...
# 266771    Male  24        28.0                  1    < 1 Year             No
# 266772    Male  41        14.0                  0    1-2 Year            Yes
# 266773    Male  44         3.0                  0    1-2 Year            Yes
# 266774    Male  38        30.0                  1    1-2 Year            Yes
# 266775    Male  48        41.0                  0    1-2 Year            Yes
#
#        Annual_Premium Policy_Sales_Channel Vintage mother_age father_age
# 0             29223.0                152.0      89         70         65
# 1             28501.0                 26.0     111         61         66
# 2             32590.0                152.0      71         67         78
# 3              2630.0                 14.0     245         74         63
# 4             31821.0                152.0      59         73         62
# ...               ...                  ...     ...        ...        ...
# 266771        49840.0                152.0      39         72         74
# 266772        31399.0                 26.0      25         63         75
# 266773        21292.0                 26.0      36         73         70
# 266774        29448.0                 26.0     117         62         76
# 266775        39092.0                 26.0     114         68         78
#
# [266776 rows x 11 columns]

# %%
Y
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 266771    0
# 266772    0
# 266773    0
# 266774    0
# 266775    0
# Name: accepted, Length: 266776, dtype: object

# %%
#creating new coluumns for categorical features
g=pd.get_dummies(X['Gender'],drop_first=True)
st=pd.get_dummies(X['Vehicle_Damage'],drop_first=True)
ut=pd.get_dummies(X['Vehicle_Age'],drop_first=True)
X=X.drop(['Gender','Vehicle_Damage','Vehicle_Age'],axis=1)

X=pd.concat([X,g,st,ut],axis=1)

# %%
X
# Out:
#        Age Region_Code Previously_Insured Annual_Premium Policy_Sales_Channel  \
# 0       23        18.0                  1        29223.0                152.0
# 1       44        23.0                  0        28501.0                 26.0
# 2       23        41.0                  0        32590.0                152.0
# 3       78        15.0                  1         2630.0                 14.0
# 4       25        44.0                  1        31821.0                152.0
# ...     ..         ...                ...            ...                  ...
# 266771  24        28.0                  1        49840.0                152.0
# 266772  41        14.0                  0        31399.0                 26.0
# 266773  44         3.0                  0        21292.0                 26.0
# 266774  38        30.0                  1        29448.0                 26.0
# 266775  48        41.0                  0        39092.0                 26.0
#
#        Vintage mother_age father_age  Male  Yes  < 1 Year  > 2 Years
# 0           89         70         65     0    0         1          0
# 1          111         61         66     1    1         0          0
# 2           71         67         78     1    1         1          0
# 3          245         74         63     1    0         0          0
# 4           59         73         62     0    0         1          0
# ...        ...        ...        ...   ...  ...       ...        ...
# 266771      39         72         74     1    0         1          0
# 266772      25         63         75     1    1         0          0
# 266773      36         73         70     1    1         0          0
# 266774     117         62         76     1    1         0          0
# 266775     114         68         78     1    1         0          0
#
# [266776 rows x 12 columns]

# %%
training_dataset
# Out:
#         Gender Age Driving_License Region_Code Previously_Insured Vehicle_Age  \
# 0       Female  23               1        18.0                  1    < 1 Year
# 1         Male  44               1        23.0                  0    1-2 Year
# 2         Male  23               1        41.0                  0    < 1 Year
# 3         Male  78               1        15.0                  1    1-2 Year
# 4       Female  25               1        44.0                  1    < 1 Year
# ...        ...  ..             ...         ...                ...         ...
# 266771    Male  24               1        28.0                  1    < 1 Year
# 266772    Male  41               1        14.0                  0    1-2 Year
# 266773    Male  44               1         3.0                  0    1-2 Year
# 266774    Male  38               1        30.0                  1    1-2 Year
# 266775    Male  48               1        41.0                  0    1-2 Year
#
#        Vehicle_Damage Annual_Premium Policy_Sales_Channel Vintage mother_age  \
# 0                  No        29223.0                152.0      89         70
# 1                 Yes        28501.0                 26.0     111         61
# 2                 Yes        32590.0                152.0      71         67
# 3                  No         2630.0                 14.0     245         74
# 4                  No        31821.0                152.0      59         73
# ...               ...            ...                  ...     ...        ...
# 266771             No        49840.0                152.0      39         72
# 266772            Yes        31399.0                 26.0      25         63
# 266773            Yes        21292.0                 26.0      36         73
# 266774            Yes        29448.0                 26.0     117         62
# 266775            Yes        39092.0                 26.0     114         68
#
#        father_age accepted
# 0              65        0
# 1              66        1
# 2              78        0
# 3              63        0
# 4              62        0
# ...           ...      ...
# 266771         74        0
# 266772         75        0
# 266773         70        0
# 266774         76        0
# 266775         78        0
#
# [266776 rows x 13 columns]

# %%
for i in range(training_dataset.shape[0]):
    if(training_dataset['Gender'][i]=='Male'):
        training_dataset['Gender'][i]='1'
    else:
        training_dataset['Gender'][i]='0'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-022be2627a34> in <module>
#       3         training_dataset['Gender'][i]='1'
#       4     else:
# ----> 5         training_dataset['Gender'][i]='0'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1043
#    1044         if cacher_needs_updating:
# -> 1045             self._maybe_update_cacher()
#    1046
#    1047     def _set_with_engine(self, key, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3280                 #  case where it will raise.  (Uh, not clear why)
#    3281                 try:
# -> 3282                     ref._maybe_cache_changed(cacher[0], self)
#    3283                 except AssertionError:
#    3284                     # ref._data.setitem can raise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _maybe_cache_changed(self, item, value)
#    3239         """The object has called back to us saying maybe it has changed.
#    3240         """
# -> 3241         self._data.set(item, value)
#    3242
#    3243     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1079
#    1080         blknos = self._blknos[loc]
# -> 1081         blklocs = self._blklocs[loc].copy()
#    1082
#    1083         unfit_mgr_locs = []
#
# KeyboardInterrupt:

# %%
## Correlation
#get correlations of each features in new dataset of training_dataset
corrmat = X.corr()
top_corr_features = corrmat.index
top_corr_features
plt.figure(figsize=(20,20))
#plot heat map
sns.heatmap(X[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#splitting of train set into training set and validation set
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

# %%
x_train.describe()
# Out:
#                 Male            Yes       < 1 Year      > 2 Years
# count  186743.000000  186743.000000  186743.000000  186743.000000
# mean        0.541932       0.506520       0.430608       0.041988
# std         0.498240       0.499959       0.495163       0.200563
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       0.000000       0.000000
# 75%         1.000000       1.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000

# %%
x_test.describe()
# Out:
#                Male           Yes      < 1 Year     > 2 Years
# count  80033.000000  80033.000000  80033.000000  80033.000000
# mean       0.541127      0.503805      0.433271      0.041945
# std        0.498309      0.499989      0.495530      0.200465
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      1.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000

# %%
print(y_train.describe())
print(186743-y_train.describe().freq)  #0-87.775% and 1-12.225%
# Out:
# count     186743
# unique         2
# top            0
# freq      163914
# Name: accepted, dtype: object
# 22829

# %%
9868/80033
# Out:
# 0.12329913910511914

# %%
print(y_test.describe())
print(80033-y_test.describe().freq)   #0-87.67% and 1-12.34%
# Out:
# count     80033
# unique        2
# top           0
# freq      70165
# Name: accepted, dtype: object
# 9868

# %% [markdown]
# ## APPLYING LOGISTIC REGRESSION

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)

# %%
## Hyper Parameter Optimization for xgboost model

params={
 "C"    : [0.10, 0.2,0.50,1.0] ,
 "max_iter"        : [50,100,150,200,250],
 "intercept_scaling" : [ 1, 3, 5, 7 ],
 "penalty"            : ['l1','l2'],
 "random_state" : [ 0,42]
    
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator = classifier,
                           param_grid=params,
                           n_jobs=-1,cv=5,verbose=3)

# %%
grid_search = grid_search.fit(X,Y)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 1552 tasks      | elapsed: 36.0min
# [Parallel(n_jobs=-1)]: Done 1600 out of 1600 | elapsed: 37.1min finished
# C:\Users\M VASIL ANSARI\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
best_accuracy
# Out:
# 0.8774365010345758

# %%
#fitting logistic regression to training data
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
#classifier.fit(x_train,y_train)

# %%
#predicting test set results
y_pred=classifier.predict(x_test)

# %%
y_pred
# Out:
# array(['0', '0', '0', ..., '0', '0', '0'], dtype=object)

# %%
new_array=list(y_test)

# %%
count_1_1=0
count_1_0=0
count_0_1=0
count_0_0=0
for i in range(80033):
    if(y_pred[i]=='0' and new_array[i]=='0'):
        count_0_0+=1
    elif(y_pred[i]=='0' and new_array[i]=='1'):
        count_0_1+=1
    elif(y_pred[i]=='1' and new_array[i]=='0'):
        count_1_0+=1
    elif(y_pred[i]=='1' and new_array[i]=='1'):
        count_1_1+=1

# %%
print(count_0_0)
print(count_1_1)
print(count_0_1)
print(count_1_0)
# Out:
# 70164
# 1
# 9867
# 1

# %%
70165+9868
# Out:
# 80033

# %%
#data visualisation
#making the confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
cm
#correct predictionss=70165,incorrect predictions=9868
# Out:
# array([[70164,     1],
#        [ 9867,     1]], dtype=int64)
